# %%
import importlib
import sys
from urllib.request import urlretrieve
import time

if 'google.colab' in sys.modules and importlib.util.find_spec('manipulation') is None:
    urlretrieve(f"http://manipulation.csail.mit.edu/scripts/setup/setup_manipulation_colab.py",
                "setup_manipulation_colab.py")
    from setup_manipulation_colab import setup_manipulation
    setup_manipulation(manipulation_sha='master', drake_version='latest', drake_build='continuous')

# Determine if this notebook is currently running as a notebook or a unit test.
from IPython import get_ipython
running_as_notebook = get_ipython() and hasattr(get_ipython(), 'kernel')

# Setup rendering (with xvfb), if necessary:
import os
if 'google.colab' in sys.modules and os.getenv("DISPLAY") is None:
    from pyvirtualdisplay import Display
    display = Display(visible=0, size=(1400, 900))
    display.start()

server_args = []
if 'google.colab' in sys.modules:
  server_args = ['--ngrok_http_tunnel']

# Start two meshcat servers (one for 2d) to use for the remainder of this notebook.
from meshcat.servers.zmqserver import start_zmq_server_as_subprocess
proc_2d, zmq_url_2d, web_url_2d = start_zmq_server_as_subprocess(server_args=server_args)
proc, zmq_url, web_url = start_zmq_server_as_subprocess(server_args=server_args)

# Imports
import numpy as np
from IPython.display import display, HTML
from ipywidgets import Textarea

from pydrake.all import ( 
    AddMultibodyPlantSceneGraph, ConnectMeshcatVisualizer, 
    DiagramBuilder, RigidTransform, RotationMatrix, Box,    
    CoulombFriction, FindResourceOrThrow, FixedOffsetFrame, 
    GeometryInstance, MeshcatContactVisualizer, Parser, PlanarJoint,  
    JointIndex, Simulator, ProcessModelDirectives, LoadModelDirectives
)

from functools import partial
import open3d as o3d
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import meshcat
import meshcat.geometry as g
import meshcat.transformations as tf

from pydrake.all import (
    ConnectPlanarSceneGraphVisualizer,
    ConnectDrakeVisualizer, DepthCameraProperties, RgbdSensor,
    RandomGenerator, UniformlyRandomRotationMatrix, RollPitchYaw,
    MakeRenderEngineVtk, RenderEngineVtkParams, Role, UnitInertia, set_log_level
)

from ipywidgets import Dropdown, FloatSlider, Layout
from pydrake.all import (
    Sphere, Cylinder, Box, Capsule, Ellipsoid, SpatialInertia)

import pydrake

#from pydrake.multibody.jupyter_widgets import MakeJointSlidersThatPublishOnCallback
from manipulation.jupyter_widgets import MakeJointSlidersThatPublishOnCallback
from manipulation.meshcat_utils import draw_open3d_point_cloud, draw_points
from manipulation.open3d_utils import create_open3d_point_cloud
from manipulation.mustard_depth_camera_example import MustardExampleSystem
from manipulation.scenarios import AddRgbdSensors
from manipulation.utils import FindResource

set_log_level("warn");

ycb = [("cracker", "003_cracker_box.sdf"), 
        ("sugar", "004_sugar_box.sdf"), 
        ("soup", "005_tomato_soup_can.sdf"), 
        ("mustard", "006_mustard_bottle.sdf"), 
        ("gelatin", "009_gelatin_box.sdf"), 
        ("meat", "010_potted_meat_can.sdf")]
# Out:
# Cloning into '/opt/manipulation'...
#
# Already on 'master'
#
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
#
# ERROR: tensorflow 2.3.0 has requirement scipy==1.4.1, but you'll have scipy 1.5.3 which is incompatible.
# ERROR: nbclient 0.5.1 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import os
import time
import numpy as np
import torch
import torch.nn as nn
import torchvision.models
import collections
import math
import torch.nn.functional as F


from google.colab import drive
drive.mount('/content/gdrive')

SAMPLES = -1
BATCH_SIZE = 10
EPOCHS = 5
IMG_SHAPE = (480, 640, 4)
POSE_SHAPE = (6,)
VAL_PROPORTION = .1
device = "cuda"
# Out:
# Mounted at /content/gdrive

# %%
# cd to relevant directory

# %%
# Define dataloader
class Dataset(torch.utils.data.Dataset):
    def __init__(self, num_items, dir_ind, val=False):
        self.x_files = []
        self.y_files = []
        for data_file_index in dir_ind:
            if val:
                x_dir = os.path.join(DATA_DIRECTORY, "xval" + str(data_file_index))
                y_dir = os.path.join(DATA_DIRECTORY, "yval" + str(data_file_index))
            else:
                x_dir = os.path.join(DATA_DIRECTORY, "x" + str(data_file_index))
                y_dir = os.path.join(DATA_DIRECTORY, "y" + str(data_file_index))
            for index in range(num_items):
                self.x_files.append(os.path.join(x_dir, str(index) + "img.npy"))
                self.y_files.append(os.path.join(y_dir, str(index) + "pose.npy"))
        self.indices = np.arange(len(self.x_files), dtype=int)
    
    def __getitem__(self, index):
        ind = self.indices[index]
        img = np.load(self.x_files[ind])
        img = torch.tensor(np.transpose(img, (2, 0, 1))) / 255.
        pose = torch.tensor(np.load(self.y_files[ind]))
        pos, rot = pose[:3], pose[3:]
        theta = 2*torch.acos(rot[0] / torch.sqrt(rot[0]**2 + rot[-1]**2))
        rot = torch.tensor([theta])
        return (img, [pos, rot])

    def __len__(self):
        return len(self.indices)

# %%
# Define neural network

def conv(in_channels, out_channels, kernel_size):
    padding = (kernel_size-1) // 2
    assert 2*padding == kernel_size-1, "parameters incorrect. kernel={}, padding={}".format(kernel_size, padding)
    return nn.Sequential(
          nn.Conv2d(in_channels,out_channels,kernel_size,stride=1,padding=padding,bias=False),
          nn.ReLU(inplace=True),
        )

def fc(in_channels, out_channels):
    return nn.Sequential(
        nn.Linear(in_channels, out_channels),
    )

class normalize(nn.Module):
    def __init__(self):
        super(normalize, self).__init__()
    def forward(self, x):
        return torch.clamp(x, 0, 2 * np.pi)


class PoseEstimatorNet(nn.Module):
    def __init__(self):
        super(PoseEstimatorNet, self).__init__()
        self.resnet = torchvision.models.resnet18()
        self.initial = conv(4, 3, 1) # in_channels = 4 for RGBAlpha
        self.fc1 = fc(1000, 256)
        self.fc2_position = fc(256, 3)
        self.fc2_rotation = fc(256, 1)
        self.normalize = normalize()
        self.relu = torch.nn.ReLU() 
    def forward(self, x):
        # Convolve to be acceptable size for resnet
        x = self.initial(x)
        # ResNet18
        x = self.resnet(x)
        # Multi-layer perceptron
        x = self.fc1(x)
        x = self.relu(x)
        x_pos = self.fc2_position(x)
        x_rot = self.fc2_rotation(x)
        x_rot = self.normalize(x_rot)

        return x_pos, x_rot

# %%
def similarity_metric(img, actual):
    L1_dist = np.abs(img - actual).mean()
    return np.exp(-L1_dist)

def inverse_graphics(img, initial_pose, max_iter = 10000, var_pos = .001, var_ori = np.pi/32):
    """
    Run MCMC to refine initial pose guesses for all objects
    """
    builder = DiagramBuilder()

    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0005)

    parser = Parser(plant)

    parser.AddModelFromFile(FindResourceOrThrow(
        "drake/examples/manipulation_station/models/bin.sdf"))
    plant.WeldFrames(plant.world_frame(), plant.GetFrameByName("bin_base"))


    rs = np.random.RandomState()  # this is for python
    generator = RandomGenerator(rs.randint(1000))  # this is for c++

    # Only generate a few objects for testing.
    for i in [2]:
        object_num = i
        sdf = FindResourceOrThrow("drake/manipulation/models/ycb/sdf/" + ycb[object_num][1])
        parser.AddModelFromFile(sdf, f"object{i}")

    plant.Finalize()

    renderer = "my_renderer"
    scene_graph.AddRenderer(
        renderer, MakeRenderEngineVtk(RenderEngineVtkParams()))
    properties = DepthCameraProperties(width=640,
                                       height=480,
                                       fov_y=np.pi / 4.0,
                                       renderer_name=renderer,
                                       z_near=0.1,
                                       z_far=10.0)
    camera = builder.AddSystem(
        RgbdSensor(parent_id=scene_graph.world_frame_id(),
                   X_PB=RigidTransform(
                       RollPitchYaw(np.pi, 0, np.pi/2.0),
                       [0, 0, .8]),
                   properties=properties,
                   show_window=False))
    camera.set_name("rgbd_sensor")
    builder.Connect(scene_graph.get_query_output_port(),
                    camera.query_object_input_port())
    builder.ExportOutput(camera.color_image_output_port(), "color_image")

    # Note: if you're running this on a local machine, then you can 
    # use drake_visualizer to see the simulation.  (It's too slow to 
    # show the meshes on meshcat).
    vis = ConnectDrakeVisualizer(
        builder, 
        scene_graph
    )
    

    diagram = builder.Build()
    simulator = Simulator(diagram)
    context = simulator.get_mutable_context()
    plant_context = plant.GetMyContextFromRoot(context)
    
    prev_pose = None
    prev_score = -np.infty
    best_pose = None
    best_score = -np.infty
    best_img = None

    z = 0.07
    for ind in range(max_iter):
        for body_index in plant.GetFloatingBaseBodies():
            if prev_pose is None:
                theta = float(initial_pose[-1][0])
                pos = np.array([initial_pose[0][0], initial_pose[0][1], z])
            else:
                theta = float(prev_pose[-1][0])
                pos = np.array([prev_pose[0][0], prev_pose[0][1], z])
                if np.random.rand() < .5:
                    delta_theta = np.random.normal(loc=0, scale=var_ori)
                    delta_position  = np.random.normal(loc=0, scale=var_pos, size=2) * 0
                else:
                    delta_theta = np.random.normal(loc=0, scale=var_ori) * 0
                    delta_position  = np.random.normal(loc=0, scale=var_pos, size=2)
                
                theta += delta_theta
                if theta < 0:
                    theta += 2 * np.pi
                pos = np.minimum(np.array([.12, .18, z]), np.maximum(np.array([-.12, -.18, z]), pos + np.array([delta_position[0], delta_position[1], 0])))
            
            tf = RigidTransform(
                rpy=RollPitchYaw(0, 0, theta), 
                p=pos
                )
            
            plant.SetFreeBodyPose(plant_context, 
                                        plant.get_body(body_index),
                                        tf)
            
        simulator.AdvanceTo(1.0 if running_as_notebook else 0.1)
        for body_index in plant.GetFloatingBaseBodies():
            tf = plant.GetFreeBodyPose(plant_context, plant.get_body(body_index))
        color_image = diagram.GetOutputPort("color_image").Eval(context).data / 255.
        if ind == 0:
            init_img = color_image

        curr_score = similarity_metric(color_image, img)
        if curr_score >= prev_score or np.random.rand() < curr_score / prev_score:
            #rpy = pydrake.common.eigen_geometry.RollPitchYaw_(tf.rotation().matrix())
            theta = np.arccos(tf.rotation().matrix()[0][0])#rpy[-1]
            translation = tf.translation()
            prev_pose = [translation, [theta]]
            prev_score = curr_score
            if curr_score > best_score:
                best_score = curr_score
                best_pose = prev_pose
                best_img = color_image
        else:
            pass
        
        if ind % (max_iter // 10) == 0 and ind != 0:
            print(str(100 * ind / max_iter) + "% complete" )

    # Make tensor
    pos, ori = best_pose
    best_pose = [torch.tensor([pos]), torch.tensor([ori])]

    return best_score, best_pose, best_img, init_img

# %%
# Distance metrics
class Loss1(nn.Module):
    def __init__(self, alpha = 1):
        super(Loss1, self).__init__()

    def forward(self, y_pred, y_target):
        position_loss = torch.sqrt((y_target[0] - y_pred[0]).pow(2).sum(dim=1)).mean()
        delta = torch.abs(y_pred[1] - y_target[1])
        orientation_loss = torch.minimum(2*np.pi - delta, delta).mean()
        return position_loss, orientation_loss

# %%
DATA_DIRECTORY = os.path.join(os.getcwd(), "data")

torch.autograd.set_detect_anomaly(True)
print("Initializing model")
model = PoseEstimatorNet()
#model.to(device)
#model.load_state_dict(torch.load(os.path.join(os.getcwd(), "checkpoints2", "epoch2loss0.04361401511535754"), map_location="cpu"))
model.load_state_dict(torch.load(os.path.join(os.getcwd(), "checkpoints2", "epoch2loss0.0037583035621693403"), map_location="cpu"))
#model.load_state_dict(torch.load(os.path.join(os.getcwd(), "checkpoints2", "epoch9loss0.006022169968406322"), map_location="cpu"))

model.eval()
test_loader = torch.utils.data.DataLoader(Dataset(50, [""], val=True), batch_size = 1)
dist_metric = Loss1()

# Plot stuff
#n_plots = 3 #len(test_loader)
#f = plt.figure(figsize=(480.*n_plots / 500., 640.*3 / 500.))
#fig, axs = plt.subplots(n_plots, 3, figsize=(640.*3 / 200., 480.*n_plots / 200.))

bad_pos = 0
not_bad = 0
avg_pos_error = 0
avg_ori_error = 0
avg_ref_pos_error = 0
avg_ref_ori_error = 0

for i, [img, label] in enumerate(test_loader):
    print("-------------------------------" + str(i) + "-------------------------------")
    TEMP = img
    np_img = np.transpose(np.array(img).squeeze(), axes=(1, 2, 0))
    pred = model(img)
    pos, ori = dist_metric(pred, label)
    print("Running MCMC...")
    # Process into usable form
    new_pred = [pred[0].squeeze(), [2*np.pi*np.random.rand()]]
    best_score, best_pose, best_img, init_img = inverse_graphics(np_img, new_pred, max_iter = 100, var_pos = .001, var_ori = np.pi/4)
    print("Done!")
    print("Actual:")
    print(label)
    print("Neural Net Predicted:")
    print(pred)
    print("Position distance: " + str(float(pos)))
    print("Orientation distance: " + str(float(ori)))
    ###
    ref_pos, ref_ori = dist_metric(best_pose, label)
    print("MCMC Refined:")
    print(best_pose)
    print("Position distance: " + str(float(ref_pos)))
    print("Orientation distance: " + str(float(ref_ori)))
    '''if i in [7, 8, 9]:
        axs[i-7, 0].imshow(np_img)
        axs[i-7, 0].set_xticklabels([])
        axs[i-7, 0].set_yticklabels([])

        axs[i-7, 1].imshow(init_img)
        axs[i-7, 1].set_xticklabels([])
        axs[i-7, 1].set_yticklabels([])
        
        axs[i-7, 2].imshow(best_img)
        axs[i-7, 2].set_xticklabels([])
        axs[i-7, 2].set_yticklabels([]) '''
    if ref_pos > .1:
        bad_pos += 1
    else:
        not_bad += 1
        avg_pos_error += pos
        avg_ori_error += ori
        avg_ref_pos_error += ref_pos
        avg_ref_ori_error += ref_ori
    #break    
''' cols = ['Observed Image', 'Neural Net Pose Render', 'MCMC Refined Pose Render']
rows = ['Run {}'.format(row) for row in ['A', 'B', 'C']]

for ax, col in zip(axs[0], cols):
    ax.set_title(col)

for ax, row in zip(axs[:,0], rows):
    ax.set_ylabel(row) '''
# Out:
# Initializing model
# -------------------------------0-------------------------------
# Running MCMC...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DrakeDeprecationWarning: Deprecated; due to be removed after 2021-03-01. Please use DepthRenderCamera instead
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:46: DrakeDeprecationWarning: Constructs an RgbdSensor in the same way as the above overload, but
# using the ``CameraProperties`` portion of ``properties`` for color
# (and label) properties, and all of ``properties`` for depth
# properties.  /
# (Deprecated.)
#
# Deprecated:
#     CameraProperties are being deprecated. Please use the RenderCamera
#     variant. This will be removed from Drake on or after 2021-03-01.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: DrakeDeprecationWarning: Extends a Diagram with the required components to interface with
# drake_visualizer. This must be called *during* Diagram building and
# uses the given ``builder`` to add relevant subsystems and connections.
#
# This is a convenience method to simplify some common boilerplate for
# adding visualization capability to a Diagram. What it does is:
#
# - adds an initialization event that sends the required load message to set up
# the visualizer with the relevant geometry,
# - adds systems PoseBundleToDrawMessage and LcmPublisherSystem to
# the Diagram and connects the draw message output to the publisher input,
# - connects the ``scene_graph`` pose bundle output to the PoseBundleToDrawMessage
# system, and
# - sets the publishing rate to 1/60 of a second (simulated time).
#
# The visualization mechanism depends on the illustration role (see
# geometry_roles for details). Specifically, only geometries with the
# illustration role assigned will be included. The visualization
# function looks for the following properties in the
# IllustrationProperties instance.
#
# | Group name | Required | Property Name | Property Type | Property
# Description | | :--------: | :------: | :-----------: |
# :-------------: | :------------------- | | phong | no | diffuse |
# Eigen::Vector4d | The rgba value of the object surface |
#
# See MakePhongIllustrationProperties() to facilitate making a compliant
# set of illustration properties.
#
# You can then connect source output ports for visualization like this:
#
#
# ::
#
#     builder->Connect(pose_output_port,
#     scene_graph.get_source_pose_port(source_id));
#
# Note:
#     The initialization event occurs when Simulator::Initialize() is
#     called (explicitly or implicitly at the start of a simulation). If
#     you aren't going to be using a Simulator, use
#     DispatchLoadMessage() to send the message yourself.
#
# Parameter ``builder``:
#     The diagram builder being used to construct the Diagram.
#
# Parameter ``scene_graph``:
#     The System in ``builder`` containing the geometry to be
#     visualized.
#
# Parameter ``lcm``:
#     An optional lcm interface through which lcm messages will be
#     dispatched. Will be allocated internally if none is supplied.
#
# Parameter ``role``:
#     An optional flag to indicate the role of the geometries to be
#     visualized; defaults to the illustration role.
#
# Precondition:
#     This method has not been previously called while building the
#     builder's current Diagram.
#
# Precondition:
#     The given ``scene_graph`` must be contained within the supplied
#     DiagramBuilder.
#
# Returns:
#     the LcmPublisherSystem (in case callers, e.g., need to change the
#     default publishing rate).
#
# See also:
#     geometry::DispatchLoadMessage() / (Deprecated.)
#
# Deprecated:
#     Please use DrakeVisualizer::AddToBuilder(). This will be removed
#     from Drake on or after 2021-03-01.
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0523, -0.1007,  0.0468]], dtype=torch.float64), tensor([[2.0746]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0472, -0.0951,  0.0704]], grad_fn=<AddmmBackward>), tensor([[0.7311]], grad_fn=<ClampBackward>))
# Position distance: 0.024733228866046165
# Orientation distance: 1.3435250510576444
# MCMC Refined:
# [tensor([[-0.0483, -0.0981,  0.0700]], dtype=torch.float64), tensor([[1.1070]], dtype=torch.float64)]
# Position distance: 0.0236513285168966
# Orientation distance: 0.9676121796079715
# -------------------------------1-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0916, -0.0541,  0.0700]], dtype=torch.float64), tensor([[2.7559]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0924, -0.0547,  0.0710]], grad_fn=<AddmmBackward>), tensor([[0.7163]], grad_fn=<ClampBackward>))
# Position distance: 0.0013965439673509078
# Orientation distance: 2.0395967955959753
# MCMC Refined:
# [tensor([[-0.0138, -0.2188,  0.0468]], dtype=torch.float64), tensor([[1.8770]], dtype=torch.float64)]
# Position distance: 0.1968760093448501
# Orientation distance: 0.8788840065928207
# -------------------------------2-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0470, -0.0701,  0.0700]], dtype=torch.float64), tensor([[1.6136]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0516, -0.0677,  0.0707]], grad_fn=<AddmmBackward>), tensor([[0.7252]], grad_fn=<ClampBackward>))
# Position distance: 0.005260874661563693
# Orientation distance: 0.888374709362266
# MCMC Refined:
# [tensor([[ 0.0508, -0.0678,  0.0700]], dtype=torch.float64), tensor([[1.4088]], dtype=torch.float64)]
# Position distance: 0.004463541200303193
# Orientation distance: 0.2048284992662217
# -------------------------------3-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0899, 0.0844, 0.0700]], dtype=torch.float64), tensor([[0.1629]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0923, 0.0886, 0.0707]], grad_fn=<AddmmBackward>), tensor([[0.6932]], grad_fn=<ClampBackward>))
# Position distance: 0.004851455107358481
# Orientation distance: 0.5302731585223298
# MCMC Refined:
# [tensor([[0.0935, 0.0876, 0.0700]], dtype=torch.float64), tensor([[0.3415]], dtype=torch.float64)]
# Position distance: 0.004799100463282873
# Orientation distance: 0.1786061332187803
# -------------------------------4-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0533, -0.0647,  0.0700]], dtype=torch.float64), tensor([[2.6682]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0519, -0.0633,  0.0702]], grad_fn=<AddmmBackward>), tensor([[0.7297]], grad_fn=<ClampBackward>))
# Position distance: 0.0020067497241381877
# Orientation distance: 1.938518610771963
# MCMC Refined:
# [tensor([[-0.0519, -0.0634,  0.0700]], dtype=torch.float64), tensor([[2.5192]], dtype=torch.float64)]
# Position distance: 0.001985894617341878
# Orientation distance: 0.1489923709512575
# -------------------------------5-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0113, 0.0384, 0.0700]], dtype=torch.float64), tensor([[1.5569]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0159, 0.0436, 0.0697]], grad_fn=<AddmmBackward>), tensor([[0.7156]], grad_fn=<ClampBackward>))
# Position distance: 0.007017848751797088
# Orientation distance: 0.8413603349968719
# MCMC Refined:
# [tensor([[0.0121, 0.0411, 0.0700]], dtype=torch.float64), tensor([[1.4852]], dtype=torch.float64)]
# Position distance: 0.0028504661018239883
# Orientation distance: 0.07170767696173508
# -------------------------------6-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.1002, 0.0061, 0.0700]], dtype=torch.float64), tensor([[0.8190]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.1040, 0.0092, 0.0709]], grad_fn=<AddmmBackward>), tensor([[0.7074]], grad_fn=<ClampBackward>))
# Position distance: 0.004962649684101663
# Orientation distance: 0.11153382866536887
# MCMC Refined:
# [tensor([[-0.1355,  0.2061,  0.0469]], dtype=torch.float64), tensor([[0.9800]], dtype=torch.float64)]
# Position distance: 0.310038978101488
# Orientation distance: 0.16100931609962676
# -------------------------------7-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0546, 0.1555, 0.0700]], dtype=torch.float64), tensor([[2.1825]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0576, 0.1628, 0.0709]], grad_fn=<AddmmBackward>), tensor([[0.6997]], grad_fn=<ClampBackward>))
# Position distance: 0.007872315847738042
# Orientation distance: 1.4828669521737368
# MCMC Refined:
# [tensor([[0.0571, 0.1569, 0.0700]], dtype=torch.float64), tensor([[2.0943]], dtype=torch.float64)]
# Position distance: 0.0028639935118486845
# Orientation distance: 0.08825650019639575
# -------------------------------8-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0202,  0.0619,  0.0700]], dtype=torch.float64), tensor([[1.3653]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0169,  0.0677,  0.0702]], grad_fn=<AddmmBackward>), tensor([[0.7184]], grad_fn=<ClampBackward>))
# Position distance: 0.0066860137574478
# Orientation distance: 0.6468503837940665
# MCMC Refined:
# [tensor([[-0.0192,  0.0784,  0.0700]], dtype=torch.float64), tensor([[0.8450]], dtype=torch.float64)]
# Position distance: 0.01650016093487512
# Orientation distance: 0.5202763079014703
# -------------------------------9-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.1118, -0.0084,  0.0700]], dtype=torch.float64), tensor([[0.1446]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.1148, -0.0065,  0.0706]], grad_fn=<AddmmBackward>), tensor([[0.6988]], grad_fn=<ClampBackward>))
# Position distance: 0.003504360432513099
# Orientation distance: 0.5541882859959426
# MCMC Refined:
# [tensor([[-0.0031,  0.2234,  0.0475]], dtype=torch.float64), tensor([[1.6800]], dtype=torch.float64)]
# Position distance: 0.2597330073321001
# Orientation distance: 1.5353844493398354
# -------------------------------10-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0483, -0.0777,  0.0700]], dtype=torch.float64), tensor([[2.0754]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0519, -0.0760,  0.0707]], grad_fn=<AddmmBackward>), tensor([[0.7366]], grad_fn=<ClampBackward>))
# Position distance: 0.003988223292033523
# Orientation distance: 1.3387767626345886
# MCMC Refined:
# [tensor([[ 0.0497, -0.0767,  0.0700]], dtype=torch.float64), tensor([[2.4914]], dtype=torch.float64)]
# Position distance: 0.001701669577034483
# Orientation distance: 0.41599969618051036
# -------------------------------11-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0392,  0.0733,  0.0700]], dtype=torch.float64), tensor([[0.1051]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0360,  0.0772,  0.0703]], grad_fn=<AddmmBackward>), tensor([[0.7138]], grad_fn=<ClampBackward>))
# Position distance: 0.005112730133999919
# Orientation distance: 0.6087495390015832
# MCMC Refined:
# [tensor([[-0.0353,  0.0759,  0.0700]], dtype=torch.float64), tensor([[0.2423]], dtype=torch.float64)]
# Position distance: 0.004665697733540839
# Orientation distance: 0.13724340559041506
# -------------------------------12-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0125, 0.0852, 0.0700]], dtype=torch.float64), tensor([[3.8439]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0161, 0.0896, 0.0700]], grad_fn=<AddmmBackward>), tensor([[0.7068]], grad_fn=<ClampBackward>))
# Position distance: 0.0057402129374642475
# Orientation distance: 3.1371484366546794
# MCMC Refined:
# [tensor([[0.0161, 0.0869, 0.0700]], dtype=torch.float64), tensor([[0.7695]], dtype=torch.float64)]
# Position distance: 0.004043752861728644
# Orientation distance: 3.074407430334698
# -------------------------------13-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0460,  0.0375,  0.0700]], dtype=torch.float64), tensor([[1.6256]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0418,  0.0434,  0.0702]], grad_fn=<AddmmBackward>), tensor([[0.7268]], grad_fn=<ClampBackward>))
# Position distance: 0.0072431482687782146
# Orientation distance: 0.898837063413154
# MCMC Refined:
# [tensor([[-0.0418,  0.0434,  0.0468]], dtype=torch.float64), tensor([[1.5668]], dtype=torch.float64)]
# Position distance: 0.024278606298667033
# Orientation distance: 0.05880139751702984
# -------------------------------14-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.1049, -0.0975,  0.0700]], dtype=torch.float64), tensor([[0.8344]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.1024, -0.0943,  0.0707]], grad_fn=<AddmmBackward>), tensor([[0.7389]], grad_fn=<ClampBackward>))
# Position distance: 0.004084790936717962
# Orientation distance: 0.0955271122511292
# MCMC Refined:
# [tensor([[-0.1024, -0.0943,  0.0700]], dtype=torch.float64), tensor([[0.9516]], dtype=torch.float64)]
# Position distance: 0.004045695136173722
# Orientation distance: 0.1171272760526525
# -------------------------------15-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.1127,  0.0846,  0.0700]], dtype=torch.float64), tensor([[3.9748]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.1078,  0.0881,  0.0706]], grad_fn=<AddmmBackward>), tensor([[0.7438]], grad_fn=<ClampBackward>))
# Position distance: 0.006058655477565706
# Orientation distance: 3.05220534680506
# MCMC Refined:
# [tensor([[-0.1107,  0.0864,  0.0700]], dtype=torch.float64), tensor([[2.3645]], dtype=torch.float64)]
# Position distance: 0.00266605360431783
# Orientation distance: 1.6102218063628988
# -------------------------------16-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0829, 0.0182, 0.0700]], dtype=torch.float64), tensor([[2.7428]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0845, 0.0212, 0.0704]], grad_fn=<AddmmBackward>), tensor([[0.7127]], grad_fn=<ClampBackward>))
# Position distance: 0.00343933628785224
# Orientation distance: 2.0300339510109957
# MCMC Refined:
# [tensor([[0.0224, 0.2280, 0.0468]], dtype=torch.float64), tensor([[1.4951]], dtype=torch.float64)]
# Position distance: 0.21956237769846554
# Orientation distance: 1.2476690949599882
# -------------------------------17-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.1127, -0.0514,  0.0700]], dtype=torch.float64), tensor([[0.6315]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.1108, -0.0458,  0.0702]], grad_fn=<AddmmBackward>), tensor([[0.7458]], grad_fn=<ClampBackward>))
# Position distance: 0.005844889623923226
# Orientation distance: 0.11435490627913403
# MCMC Refined:
# [tensor([[-0.1175, -0.0449,  0.0700]], dtype=torch.float64), tensor([[0.6539]], dtype=torch.float64)]
# Position distance: 0.008052232590217845
# Orientation distance: 0.022453975488842537
# -------------------------------18-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0335,  0.1704,  0.0700]], dtype=torch.float64), tensor([[1.8234]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0279,  0.1750,  0.0704]], grad_fn=<AddmmBackward>), tensor([[0.7030]], grad_fn=<ClampBackward>))
# Position distance: 0.007249430445028247
# Orientation distance: 1.1204160593371677
# MCMC Refined:
# [tensor([[-0.0288,  0.1760,  0.0700]], dtype=torch.float64), tensor([[1.2478]], dtype=torch.float64)]
# Position distance: 0.007291810071065466
# Orientation distance: 0.5756067900159283
# -------------------------------19-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0975, 0.1452, 0.0700]], dtype=torch.float64), tensor([[0.5553]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0973, 0.1475, 0.0703]], grad_fn=<AddmmBackward>), tensor([[0.6850]], grad_fn=<ClampBackward>))
# Position distance: 0.002363265141871882
# Orientation distance: 0.12967171936533417
# MCMC Refined:
# [tensor([[-0.0351, -0.1474,  0.0468]], dtype=torch.float64), tensor([[1.3205]], dtype=torch.float64)]
# Position distance: 0.32207453002351516
# Orientation distance: 0.7651680843315899
# -------------------------------20-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0027,  0.0005,  0.0700]], dtype=torch.float64), tensor([[3.7022]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0004, 0.0063, 0.0701]], grad_fn=<AddmmBackward>), tensor([[0.7170]], grad_fn=<ClampBackward>))
# Position distance: 0.006571070897331953
# Orientation distance: 2.9851939212545227
# MCMC Refined:
# [tensor([[0.0106, 0.0056, 0.0700]], dtype=torch.float64), tensor([[2.2342]], dtype=torch.float64)]
# Position distance: 0.01422942791655862
# Orientation distance: 1.468024017520598
# -------------------------------21-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0914, 0.1484, 0.0700]], dtype=torch.float64), tensor([[0.0327]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0953, 0.1517, 0.0700]], grad_fn=<AddmmBackward>), tensor([[0.6769]], grad_fn=<ClampBackward>))
# Position distance: 0.005114915042924911
# Orientation distance: 0.6442736987274974
# MCMC Refined:
# [tensor([[-0.1317, -0.0101,  0.0468]], dtype=torch.float64), tensor([[2.3282]], dtype=torch.float64)]
# Position distance: 0.2746494709975286
# Orientation distance: 2.295565803317684
# -------------------------------22-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0412,  0.0382,  0.0700]], dtype=torch.float64), tensor([[1.9702]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0380,  0.0436,  0.0698]], grad_fn=<AddmmBackward>), tensor([[0.7315]], grad_fn=<ClampBackward>))
# Position distance: 0.006291649948772784
# Orientation distance: 1.2386638315898857
# MCMC Refined:
# [tensor([[-0.0345,  0.0399,  0.0700]], dtype=torch.float64), tensor([[1.9742]], dtype=torch.float64)]
# Position distance: 0.006853006989249741
# Orientation distance: 0.003974093223721997
# -------------------------------23-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0047, -0.1135,  0.0700]], dtype=torch.float64), tensor([[0.0081]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0066, -0.1123,  0.0701]], grad_fn=<AddmmBackward>), tensor([[0.7299]], grad_fn=<ClampBackward>))
# Position distance: 0.0022796009372093476
# Orientation distance: 0.7218172401702851
# MCMC Refined:
# [tensor([[ 0.0054, -0.1161,  0.0700]], dtype=torch.float64), tensor([[0.0004]], dtype=torch.float64)]
# Position distance: 0.0026782402194953907
# Orientation distance: 0.007665856634224299
# -------------------------------24-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0586, -0.0877,  0.0700]], dtype=torch.float64), tensor([[0.9115]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0605, -0.0855,  0.0708]], grad_fn=<AddmmBackward>), tensor([[0.7315]], grad_fn=<ClampBackward>))
# Position distance: 0.003003329469785303
# Orientation distance: 0.17999899975240208
# MCMC Refined:
# [tensor([[ 0.0605, -0.0855,  0.0468]], dtype=torch.float64), tensor([[0.8915]], dtype=torch.float64)]
# Position distance: 0.023350118824800686
# Orientation distance: 0.01997717989022385
# -------------------------------25-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0082, 0.1616, 0.0700]], dtype=torch.float64), tensor([[1.1264]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0132, 0.1680, 0.0705]], grad_fn=<AddmmBackward>), tensor([[0.6964]], grad_fn=<ClampBackward>))
# Position distance: 0.008108579281518556
# Orientation distance: 0.4299642608000531
# MCMC Refined:
# [tensor([[0.0101, 0.1627, 0.0700]], dtype=torch.float64), tensor([[1.0505]], dtype=torch.float64)]
# Position distance: 0.0020968247912657944
# Orientation distance: 0.07588760377831827
# -------------------------------26-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.1058, -0.1665,  0.0700]], dtype=torch.float64), tensor([[1.9006]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.1064, -0.1690,  0.0703]], grad_fn=<AddmmBackward>), tensor([[0.7511]], grad_fn=<ClampBackward>))
# Position distance: 0.002591456402416147
# Orientation distance: 1.1494589457786113
# MCMC Refined:
# [tensor([[-0.1050, -0.1677,  0.0700]], dtype=torch.float64), tensor([[1.9353]], dtype=torch.float64)]
# Position distance: 0.0013969012438758597
# Orientation distance: 0.03475572475847355
# -------------------------------27-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.1125, -0.1547,  0.0700]], dtype=torch.float64), tensor([[1.9856]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.1162, -0.1579,  0.0714]], grad_fn=<AddmmBackward>), tensor([[0.7396]], grad_fn=<ClampBackward>))
# Position distance: 0.005052715548368643
# Orientation distance: 1.2459435064819826
# MCMC Refined:
# [tensor([[-0.0962, -0.1823,  0.0468]], dtype=torch.float64), tensor([[0.3537]], dtype=torch.float64)]
# Position distance: 0.21179476270180825
# Orientation distance: 1.6318425639007388
# -------------------------------28-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0366, -0.1043,  0.0700]], dtype=torch.float64), tensor([[0.3021]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0397, -0.1040,  0.0705]], grad_fn=<AddmmBackward>), tensor([[0.7334]], grad_fn=<ClampBackward>))
# Position distance: 0.0031822423072326777
# Orientation distance: 0.43130107221409053
# MCMC Refined:
# [tensor([[ 0.0410, -0.1010,  0.0700]], dtype=torch.float64), tensor([[0.3231]], dtype=torch.float64)]
# Position distance: 0.0055234227259758325
# Orientation distance: 0.020947074401619137
# -------------------------------29-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0803, -0.0738,  0.0700]], dtype=torch.float64), tensor([[2.9172]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0820, -0.0741,  0.0710]], grad_fn=<AddmmBackward>), tensor([[0.7299]], grad_fn=<ClampBackward>))
# Position distance: 0.0019707816337440967
# Orientation distance: 2.1872717975710683
# MCMC Refined:
# [tensor([[ 0.0841, -0.0724,  0.0700]], dtype=torch.float64), tensor([[3.0275]], dtype=torch.float64)]
# Position distance: 0.003975488543935468
# Orientation distance: 0.11024920279285055
# -------------------------------30-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0732, -0.1101,  0.0700]], dtype=torch.float64), tensor([[1.7372]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0709, -0.1085,  0.0706]], grad_fn=<AddmmBackward>), tensor([[0.7413]], grad_fn=<ClampBackward>))
# Position distance: 0.0028523092539528986
# Orientation distance: 0.9959168963276899
# MCMC Refined:
# [tensor([[-0.0694, -0.1065,  0.0700]], dtype=torch.float64), tensor([[1.8572]], dtype=torch.float64)]
# Position distance: 0.005238227205541276
# Orientation distance: 0.11996389390414453
# -------------------------------31-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0292, 0.0497, 0.0700]], dtype=torch.float64), tensor([[1.3003]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0342, 0.0549, 0.0697]], grad_fn=<AddmmBackward>), tensor([[0.7154]], grad_fn=<ClampBackward>))
# Position distance: 0.007246840214619646
# Orientation distance: 0.5849184805120635
# MCMC Refined:
# [tensor([[0.0342, 0.0549, 0.0468]], dtype=torch.float64), tensor([[1.2169]], dtype=torch.float64)]
# Position distance: 0.02427211270078897
# Orientation distance: 0.08333298506536302
# -------------------------------32-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0239, -0.0647,  0.0700]], dtype=torch.float64), tensor([[0.8274]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0277, -0.0626,  0.0701]], grad_fn=<AddmmBackward>), tensor([[0.7218]], grad_fn=<ClampBackward>))
# Position distance: 0.00430674709724609
# Orientation distance: 0.10559405135661093
# MCMC Refined:
# [tensor([[ 0.0275, -0.0632,  0.0700]], dtype=torch.float64), tensor([[0.3365]], dtype=torch.float64)]
# Position distance: 0.0038848939087076178
# Orientation distance: 0.4908521740016557
# -------------------------------33-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0780,  0.1793,  0.0700]], dtype=torch.float64), tensor([[1.5708]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0711,  0.1793,  0.0718]], grad_fn=<AddmmBackward>), tensor([[0.7004]], grad_fn=<ClampBackward>))
# Position distance: 0.007149462103203271
# Orientation distance: 0.8704829420876714
# MCMC Refined:
# [tensor([[-0.0769,  0.1800,  0.0700]], dtype=torch.float64), tensor([[1.5195]], dtype=torch.float64)]
# Position distance: 0.001288342657874341
# Orientation distance: 0.051305137210507334
# -------------------------------34-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.1159, -0.1185,  0.0700]], dtype=torch.float64), tensor([[1.4476]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.1204, -0.1204,  0.0716]], grad_fn=<AddmmBackward>), tensor([[0.7208]], grad_fn=<ClampBackward>))
# Position distance: 0.0050929490491957346
# Orientation distance: 0.7268199924465597
# MCMC Refined:
# [tensor([[ 0.0789, -0.1238,  0.0630]], dtype=torch.float64), tensor([[1.6053]], dtype=torch.float64)]
# Position distance: 0.03808899346202346
# Orientation distance: 0.15767674912277618
# -------------------------------35-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0334, -0.1761,  0.0700]], dtype=torch.float64), tensor([[1.5923]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0288, -0.1773,  0.0706]], grad_fn=<AddmmBackward>), tensor([[0.7400]], grad_fn=<ClampBackward>))
# Position distance: 0.0048204870917589685
# Orientation distance: 0.8523742112160895
# MCMC Refined:
# [tensor([[-0.0309, -0.1716,  0.0700]], dtype=torch.float64), tensor([[1.6427]], dtype=torch.float64)]
# Position distance: 0.005179956972162776
# Orientation distance: 0.05039158730811155
# -------------------------------36-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0670, -0.0297,  0.0700]], dtype=torch.float64), tensor([[2.8594]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0700, -0.0280,  0.0710]], grad_fn=<AddmmBackward>), tensor([[0.7223]], grad_fn=<ClampBackward>))
# Position distance: 0.003606068864260115
# Orientation distance: 2.13711799681905
# MCMC Refined:
# [tensor([[ 0.0692, -0.0291,  0.0700]], dtype=torch.float64), tensor([[2.7807]], dtype=torch.float64)]
# Position distance: 0.0022836292236629936
# Orientation distance: 0.07867827736298505
# -------------------------------37-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0288, -0.1351,  0.0700]], dtype=torch.float64), tensor([[0.0232]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0323, -0.1330,  0.0703]], grad_fn=<AddmmBackward>), tensor([[0.7324]], grad_fn=<ClampBackward>))
# Position distance: 0.0040594728340330385
# Orientation distance: 0.7091683473943563
# MCMC Refined:
# [tensor([[ 0.0358, -0.1340,  0.0700]], dtype=torch.float64), tensor([[0.0963]], dtype=torch.float64)]
# Position distance: 0.007071568532547698
# Orientation distance: 0.07307333116352867
# -------------------------------38-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0726, -0.1024,  0.0700]], dtype=torch.float64), tensor([[1.2009]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0696, -0.1007,  0.0706]], grad_fn=<AddmmBackward>), tensor([[0.7444]], grad_fn=<ClampBackward>))
# Position distance: 0.0034686197730108216
# Orientation distance: 0.45651490107372883
# MCMC Refined:
# [tensor([[-0.0710, -0.1058,  0.0700]], dtype=torch.float64), tensor([[0.6906]], dtype=torch.float64)]
# Position distance: 0.0038261617564430165
# Orientation distance: 0.5103806164618571
# -------------------------------39-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0645, 0.0604, 0.0700]], dtype=torch.float64), tensor([[0.6837]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0679, 0.0647, 0.0701]], grad_fn=<AddmmBackward>), tensor([[0.7091]], grad_fn=<ClampBackward>))
# Position distance: 0.0055450799579989775
# Orientation distance: 0.025335553892688267
# MCMC Refined:
# [tensor([[0.0665, 0.0584, 0.0700]], dtype=torch.float64), tensor([[0.6593]], dtype=torch.float64)]
# Position distance: 0.0028403481122561925
# Orientation distance: 0.024419566936959014
# -------------------------------40-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.1170, -0.0772,  0.0700]], dtype=torch.float64), tensor([[2.4052]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.1210, -0.0784,  0.0709]], grad_fn=<AddmmBackward>), tensor([[0.7146]], grad_fn=<ClampBackward>))
# Position distance: 0.004259925498398295
# Orientation distance: 1.6905612469363036
# MCMC Refined:
# [tensor([[0.0277, 0.1336, 0.0468]], dtype=torch.float64), tensor([[1.7259]], dtype=torch.float64)]
# Position distance: 0.23014687289167124
# Orientation distance: 0.6792600751433631
# -------------------------------41-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0649, 0.0535, 0.0700]], dtype=torch.float64), tensor([[3.4315]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0684, 0.0570, 0.0697]], grad_fn=<AddmmBackward>), tensor([[0.7193]], grad_fn=<ClampBackward>))
# Position distance: 0.004934161071512845
# Orientation distance: 2.712210913800701
# MCMC Refined:
# [tensor([[0.0663, 0.0529, 0.0700]], dtype=torch.float64), tensor([[3.1228]], dtype=torch.float64)]
# Position distance: 0.0015081568480540225
# Orientation distance: 0.308660812167425
# -------------------------------42-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0091, -0.1249,  0.0700]], dtype=torch.float64), tensor([[3.6815]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0134, -0.1239,  0.0703]], grad_fn=<AddmmBackward>), tensor([[0.7374]], grad_fn=<ClampBackward>))
# Position distance: 0.00434141072853807
# Orientation distance: 2.9440190972014664
# MCMC Refined:
# [tensor([[ 0.0131, -0.1280,  0.0700]], dtype=torch.float64), tensor([[2.6603]], dtype=torch.float64)]
# Position distance: 0.0050059611233463815
# Orientation distance: 1.0211957696454648
# -------------------------------43-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0099,  0.0763,  0.0700]], dtype=torch.float64), tensor([[3.0418]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0066,  0.0812,  0.0698]], grad_fn=<AddmmBackward>), tensor([[0.7089]], grad_fn=<ClampBackward>))
# Position distance: 0.00595171383792402
# Orientation distance: 2.332863289219881
# MCMC Refined:
# [tensor([[-0.0102,  0.0827,  0.0700]], dtype=torch.float64), tensor([[2.9390]], dtype=torch.float64)]
# Position distance: 0.006412357753028205
# Orientation distance: 0.10282142448496367
# -------------------------------44-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[0.0022, 0.1233, 0.0700]], dtype=torch.float64), tensor([[3.6999]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[0.0056, 0.1283, 0.0703]], grad_fn=<AddmmBackward>), tensor([[0.7049]], grad_fn=<ClampBackward>))
# Position distance: 0.006036799344177554
# Orientation distance: 2.9950060312774434
# MCMC Refined:
# [tensor([[-0.0005,  0.1216,  0.0700]], dtype=torch.float64), tensor([[2.5683]], dtype=torch.float64)]
# Position distance: 0.003211018348501839
# Orientation distance: 1.1316420545766217
# -------------------------------45-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0709, -0.1482,  0.0700]], dtype=torch.float64), tensor([[1.0606]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0764, -0.1495,  0.0703]], grad_fn=<AddmmBackward>), tensor([[0.7481]], grad_fn=<ClampBackward>))
# Position distance: 0.0056735531710398485
# Orientation distance: 0.3125746126470763
# MCMC Refined:
# [tensor([[ 0.0642, -0.1796,  0.0700]], dtype=torch.float64), tensor([[2.6461]], dtype=torch.float64)]
# Position distance: 0.03210304080986658
# Orientation distance: 1.5854198588412758
# -------------------------------46-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0846,  0.0013,  0.0700]], dtype=torch.float64), tensor([[3.0438]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0824,  0.0065,  0.0701]], grad_fn=<AddmmBackward>), tensor([[0.7360]], grad_fn=<ClampBackward>))
# Position distance: 0.005616114059391664
# Orientation distance: 2.307832133163171
# MCMC Refined:
# [tensor([[-0.0832,  0.0049,  0.0700]], dtype=torch.float64), tensor([[3.0954]], dtype=torch.float64)]
# Position distance: 0.003841902313652761
# Orientation distance: 0.051582162165155765
# -------------------------------47-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[ 0.0076, -0.1269,  0.0700]], dtype=torch.float64), tensor([[2.3877]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[ 0.0118, -0.1273,  0.0699]], grad_fn=<AddmmBackward>), tensor([[0.7361]], grad_fn=<ClampBackward>))
# Position distance: 0.004228918431021092
# Orientation distance: 1.6515984982443168
# MCMC Refined:
# [tensor([[ 0.0084, -0.1216,  0.0700]], dtype=torch.float64), tensor([[2.2614]], dtype=torch.float64)]
# Position distance: 0.005353940426234335
# Orientation distance: 0.12635331993032528
# -------------------------------48-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0503, -0.0014,  0.0700]], dtype=torch.float64), tensor([[1.8521]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0485,  0.0042,  0.0704]], grad_fn=<AddmmBackward>), tensor([[0.7314]], grad_fn=<ClampBackward>))
# Position distance: 0.005948064924520576
# Orientation distance: 1.1206906706723445
# MCMC Refined:
# [tensor([[-4.9726e-02, -1.5412e-05,  7.0000e-02]], dtype=torch.float64), tensor([[1.8772]], dtype=torch.float64)]
# Position distance: 0.001557956074090957
# Orientation distance: 0.02512841299474111
# -------------------------------49-------------------------------
# Running MCMC...
# 10.0% complete
# 20.0% complete
# 30.0% complete
# 40.0% complete
# 50.0% complete
# 60.0% complete
# 70.0% complete
# 80.0% complete
# 90.0% complete
# Done!
# Actual:
# [tensor([[-0.0911, -0.1586,  0.0700]], dtype=torch.float64), tensor([[2.7515]], dtype=torch.float64)]
# Neural Net Predicted:
# (tensor([[-0.0890, -0.1580,  0.0709]], grad_fn=<AddmmBackward>), tensor([[0.7466]], grad_fn=<ClampBackward>))
# Position distance: 0.002318794105203277
# Orientation distance: 2.004817133483361
# MCMC Refined:
# [tensor([[-0.0868, -0.1575,  0.0700]], dtype=torch.float64), tensor([[2.8870]], dtype=torch.float64)]
# Position distance: 0.004421500299626562
# Orientation distance: 0.13554729059552084
# " cols = ['Observed Image', 'Neural Net Pose Render', 'MCMC Refined Pose Render']\nrows = ['Run {}'.format(row) for row in ['A', 'B', 'C']]\n\nfor ax, col in zip(axs[0], cols):\n    ax.set_title(col)\n\nfor ax, row in zip(axs[:,0], rows):\n    ax.set_ylabel(row) "

# %%
print(bad_pos)
print(np.array([avg_pos_error, avg_ori_error, avg_ref_pos_error, avg_ref_ori_error]) / float(not_bad))
# Out:
# 8
# [tensor(0.0055, dtype=torch.float64, grad_fn=<DivBackward0>)
#  tensor(1.2668, dtype=torch.float64, grad_fn=<DivBackward0>)
#  tensor(0.0079, dtype=torch.float64) tensor(0.3824, dtype=torch.float64)]
